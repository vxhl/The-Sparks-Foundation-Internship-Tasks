# %% [markdown]
# # GRIP ( Graduate Rotational Internship Program ) @ The Sparks Foundation
#
# ## Author: Bishal Mohari

# %% [markdown]
# 📈 **Project Showcase**: ***Prediction using Supervised learning algorithm for the House Prices Dataset***

# %% [markdown]
# **Aim of the project**: Predict the percentage of an student based on the no. of study hours.
# What will be predicted score if a student studies for 9.25 hrs/ day?

# %% [markdown]
# # 📈( except there's no break in the plotted line )Simple Linear Regression:
# It concerns two-dimensional sample points with one independent variable and one dependent variable (conventionally, the x and y coordinates in a Cartesian coordinate system) and finds a linear function (a non-vertical straight line) that, as accurately as possible, predicts the dependent variable values as a function of the independent variable.
#
# As we can see, our linear regression creates the line of best fit in accordance with the values in our variables.
# ![image.png](attachment:image.png)
#
# But how is this line of best fit chosen considering there can be a number of lines that can be made similar to this?
# ![image-2.png](attachment:image-2.png)
#
# Inorder to determine that we get the distances of each point from the regressor line, square those values and then take the line that has the minimum value and plot it across our points.
# ![image-3.png](attachment:image-3.png)
#
# The line as you may know is plotted using the following formula:
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Step 1: Importing the Libraries

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 2: Importing the dataset

# %%
url = r"https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
df = pd.read_csv(url)
print("Data import successful")
df.head(10)
# Out:
# Data import successful
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
# Plotting the distribution of scores
df.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %% [markdown]
# As we can from our visualization, our dataset shows a linear relation between the number of hours studied and Percentage of score.

# %%
df.shape
# Out:
# (25, 2)

# %% [markdown]
# # Step 3: Data Preprocessing

# %% [markdown]
# Let us first define our dependent and independent variables

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,1].values

# %% [markdown]
# ## Step 4: Training the Model

# %% [markdown]
# Split the data into training and testing sets for training the model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) 
regressor = LinearRegression()  
regressor.fit(X_train.reshape(-1,1), y_train) 

print("Training complete.")
# Out:
# Training complete.

# %% [markdown]
# ## Step 5 - Plotting the Line of regression
# Let us now visualize our Linear Regression line and see if it gets the best-fit.

# %%
m = regressor.coef_

# %%
b = regressor.intercept_

# %% [markdown]
# ### We use Y = mx + b => line = m*X+b for building the regression line

# %%
# Plotting the regression line
line = m*X+b
# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, line,color='red');
plt.show()
# Out:
# The value for the line is:  [[26.79480124]
#  [52.56250809]
#  [33.73226078]
#  [86.25874013]
#  [36.70545772]
#  [16.88414476]
#  [93.19619966]
#  [56.52677068]
#  [84.27660883]
#  [28.77693254]
#  [78.33021494]
#  [60.49103328]
#  [46.6161142 ]
#  [34.72332643]
#  [12.91988217]
#  [90.22300272]
#  [26.79480124]
#  [20.84840735]
#  [62.47316457]
#  [75.357018  ]
#  [28.77693254]
#  [49.58931115]
#  [39.67865467]
#  [70.40168976]
#  [79.32128059]]

# %% [markdown]
# ## Step 6 - Making Predictions

# %%
# Model Prediction 
y_pred = regressor.predict(X_test)

# %%
# Comparing Actual vs Predicted
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred}) 
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
#Estimating training and test score
print("Training Score:",regressor.score(X_train,y_train))
print("Test Score:",regressor.score(X_test,y_test))
# Out:
# Training Score: 0.9515510725211552
# Test Score: 0.9454906892105354

# %%
# Plotting the Bar graph to depict the difference between the actual and predicted value

df.plot(kind='bar',figsize=(5,5))
plt.grid(which='major', linewidth='0.5', color='red')
plt.grid(which='minor', linewidth='0.5', color='blue')
plt.show()

# %%
# Testing the model with our own data
hours = 9.25
test = np.array([hours])
test = test.reshape(-1, 1)
own_pred = regressor.predict(test)
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(own_pred[0]))
# Out:
# No of Hours = 9.25
# Predicted Score = 93.69173248737539

# %% [markdown]
# ## Step 7: Model Evaluation
# The final step is to evaluate the performance of algorithm. This step is particularly important to compare how well different algorithms perform on a particular dataset. Here different errors have been calculated to compare the model performance and predict the accuracy.

# %%
from sklearn import metrics  
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test, y_pred)) 
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R^2:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982
# Mean Squared Error: 21.598769307217456
# Root Mean Squared Error: 4.647447612100373
# R^2: 0.9454906892105354

# %% [markdown]
# R-squared is a measure of how close each data point fits to the regression line. Tells us how well the regerssion line predicts actual values.
#
# R^2 gives the score of model fit and in this case we have R^2 = 0.9454906892105355 which is actually a great score for this model.
#
# ## Conclusion
#
# ### I was successfully able to carry-out Prediction using Supervised ML task and was able to evaluate the model's performance on various parameters.
# # Thank You
